# %% [markdown]
# <a href="https://colab.research.google.com/github/yashromakarona/myCodePractice/blob/main/dl_02_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x = np.array([2,4,6,8,10,12,14])
y = np.array([0,0,0,1,1,1,1])

model = Sequential()
model.add(Dense(1,input_dim=1, activation='sigmoid'))

model.compile(optimizer='sgd', loss='binary_crossentropy')
model.fit(x,y,epochs=1000)

plt.scatter(x,y)
plt.plot(x, model.predict(x), 'r')
plt.show()

hour = 7
input_data = tf.constant([[hour]], dtype=tf.float32)
prediction = model.predict(input_data)[0][0]

print("%.f시간을 공부할 경우, 합격 예상 확률은 %.01f%%입니다" % (hour, prediction*100))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step - loss: 0.7454
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.7274
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.7103
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.6940
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.6786
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.6641
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.6505
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.6379
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.6263
# Epoch 10/1000
# ...
